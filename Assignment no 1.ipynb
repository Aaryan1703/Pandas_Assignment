# %% [markdown]
# # Hitters Dataset

# %% [markdown]
# # Reading Data Set

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Aryan\\OneDrive\\Desktop\\DataSet\\hitters.csv")
df.head()
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     Andy Allanson    293    66      1    30   29     14      1     293
# 1        Alan Ashby    315    81      7    24   38     39     14    3449
# 2       Alvin Davis    479   130     18    66   72     76      3    1624
# 3      Andre Dawson    496   141     20    65   78     37     11    5628
# 4  Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
#
#    Salary  NewLeague
# 0     NaN          A
# ...

# %%
df.shape
# Out:
# (322, 21)

# %%
df.columns
# Out:
# Index(['Name', 'AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years',
#        'CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'League',
#        'Division', 'PutOuts', 'Assists', 'Errors', 'Salary', 'NewLeague'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       322 non-null    object
#  1   AtBat      322 non-null    int64
#  2   Hits       322 non-null    int64
#  3   HmRun      322 non-null    int64
#  4   Runs       322 non-null    int64
#  5   RBI        322 non-null    int64
#  6   Walks      322 non-null    int64
#  7   Years      322 non-null    int64
#  8   CAtBat     322 non-null    int64
#  9   CHits      322 non-null    int64
#  10  CHmRun     322 non-null    int64
#  11  CRuns      322 non-null    int64
#  12  CRBI       322 non-null    int64
#  13  CWalks     322 non-null    int64
#  14  League     322 non-null    object
#  15  Division   322 non-null    object
#  16  PutOuts    322 non-null    int64
#  17  Assists    322 non-null    int64
#  18  Errors     322 non-null    int64
#  19  Salary     263 non-null    float64
# ...

# %% [markdown]
# ## Que 1: Find out no of missing values in each column

# %%
df.isnull().sum()
# Out:
# Name          0
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64

# %% [markdown]
# ## fill missing values

# %%
me=df["Salary"].mean()
me
# Out:
# 535.9258821292775

# %%
df["Salary"]=df["Salary"].fillna(me)

# %%
df.isnull().sum()
# Out:
# Name         0
# AtBat        0
# Hits         0
# HmRun        0
# Runs         0
# RBI          0
# Walks        0
# Years        0
# CAtBat       0
# CHits        0
# CHmRun       0
# CRuns        0
# CRBI         0
# CWalks       0
# League       0
# Division     0
# PutOuts      0
# Assists      0
# Errors       0
# Salary       0
# NewLeague    0
# dtype: int64

# %% [markdown]
# ## Que 2: Find of people who have batted for more than 400 matches

# %%
df[df["AtBat"]>400][["Name","AtBat"]]
# Out:
#                 Name  AtBat
# 2        Alvin Davis    479
# 3       Andre Dawson    496
# 5    Alfredo Griffin    594
# 9     Andre Thornton    401
# 10     Alan Trammell    574
# ..               ...    ...
# 317     Willie McGee    497
# 318  Willie Randolph    492
# 319   Wayne Tolleson    475
# 320    Willie Upshaw    573
# 321    Willie Wilson    631
#
# [151 rows x 2 columns]

# %% [markdown]
# ## Que 3: Find out the name of the player who has hit max home runs

# %%
m=df["CHmRun"].max()
m
# Out:
# 548

# %%
df[df["CHmRun"]==m][["Name","CHmRun"]]
# Out:
#                Name  CHmRun
# 249  Reggie Jackson     548

# %% [markdown]
# ## Que 3: Find out league wise total number of players

# %%
league=df.groupby(by="League")
league

# %%
df["League"].unique()
# Out:
# array(['A', 'N'], dtype=object)

# %%
league.count()["Name"]
# Out:
# League
# A    175
# N    147
# Name: Name, dtype: int64

# %% [markdown]
# ## Que 4: Find out division wise total amount of salary invested

# %%
df
# Out:
#                  Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       Andy Allanson    293    66      1    30   29     14      1     293
# 1          Alan Ashby    315    81      7    24   38     39     14    3449
# 2         Alvin Davis    479   130     18    66   72     76      3    1624
# 3        Andre Dawson    496   141     20    65   78     37     11    5628
# 4    Andres Galarraga    321    87     10    39   42     30      2     396
# ..                ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      Willie McGee    497   127      7    65   48     37      5    2703
# 318   Willie Randolph    492   136      5    76   50     94     12    5511
# 319    Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %%
df["Division"].unique()
# Out:
# array(['E', 'W'], dtype=object)

# %%
e=df.groupby(by="Division")
e

# %%
e.sum()[["Salary"]]
# Out:
#                 Salary
# Division
# E         95536.930700
# W         77031.203346

# %% [markdown]
# ## Que 5: Find out five most senior players.

# %%
df.sort_values(by="Years", ascending=False).head()[["Name","AtBat","HmRun","Years"]]
# Out:
#                Name  AtBat  HmRun  Years
# 236       Pete Rose    237      0     24
# 302      Tony Perez    200      2     23
# 121   Graig Nettles    354     16     20
# 249  Reggie Jackson    419     18     20
# 306     Ted Simmons    127      4     19

# %% [markdown]
# # Cars Dataset

# %% [markdown]
# ## importing data set

# %%
import pandas as pd
df2=pd.read_csv("C:\\Users\\Aryan\\OneDrive\\Desktop\\DataSet\\Cars93.csv")
df2
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
df2.shape
# Out:
# (93, 28)

# %%
df2.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             89 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %% [markdown]
# ## filling missing value

# %%
for i in df2.columns:
    if(df2[i].dtypes=="object"):
        md=df2[i].mode()
        df2[i]=df2[i].fillna(md)
    elif(df2[i].dtypes!="object"):
        me=df2[i].mean()
        df2[i]=df2[i].fillna(me)

# %%
df2.isnull().sum()
# Out:
# id                    0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               4
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %% [markdown]
# ## Que 1: Find out car having highest Mileage in city

# %%
max_milage=df2["MPG.city"].max()
max_milage
# Out:
# 46

# %%
df2[df2["MPG.city"]==max_milage]
# Out:
#     id Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo  Metro  Small        6.7    8.4       10.0        46
#
#     MPG.highway AirBags  ... Passengers Length  Wheelbase  Width  Turn.circle  \
# 38           50    None  ...          4    151         93     63           34
#
#     Rear.seat.room Luggage.room  Weight   Origin       Make
# 38            27.5         10.0    1695  non-USA  Geo Metro
#
# [1 rows x 28 columns]

# %% [markdown]
# ## Que 2:Find out Models of cars which are having Price between 17 and 25

# %%
df2[(df2["Price"]>=17)&(df2["Price"]<25)][["Model","Price"]]
# Out:
#              Model  Price
# 6          LeSabre   20.8
# 7       Roadmaster   23.7
# 17         Caprice   18.8
# 19        Concorde   18.4
# 25         Caravan   19.0
# 29          Vision   19.3
# 35        Aerostar   19.9
# 36          Taurus   20.2
# 37  Crown_Victoria   20.9
# 40         Prelude   19.8
# 42          Accord   17.5
# 55             MPV   19.1
# 65           Quest   19.1
# 66          Maxima   21.5
# 69      Silhouette   19.5
# 70    Eighty-Eight   20.7
# 74        Firebird   17.7
# 75      Grand_Prix   18.5
# 76      Bonneville   24.4
# 81          Legacy   19.5
# 84          Celica   18.4
# 85           Camry   18.2
# 86          Previa   22.7
# 88         Eurovan   19.7
# 89          Passat   20.0
# 90         Corrado   23.3
# 91             240   22.7

# %% [markdown]
# ## Que 3: Find out top 7 most fuel economic cars for highway

# %%
df2.sort_values(by="MPG.highway",ascending=False).head(7)
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo   Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki   Swift  Small        7.3    8.6       10.0        39
# 72  73      Pontiac  LeMans  Small        8.2    9.0        9.9        31
# 78  79       Saturn      SL  Small        9.2   11.1       12.9        28
# 83  84       Toyota  Tercel  Small        7.8    9.8       11.8        32
# 79  80       Subaru   Justy  Small        7.3    8.4        9.5        33
#
#     MPG.highway      AirBags  ... Passengers Length  Wheelbase  Width  \
# 38           50         None  ...          4    151         93     63
# 41           46  Driver only  ...          4    173        103     67
# 82           43         None  ...          4    161         93     63
# 72           41         None  ...          4    177         99     66
# ...

# %% [markdown]
# ## Que 4: Find out Models of cars having no AirBags and which are of compact type whose price is below 20.

# %%
df2["AirBags"].unique()
# Out:
# array(['None', 'Driver & Passenger', 'Driver only', nan], dtype=object)

# %%
df2["Type"].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
df2[(df2["AirBags"]=="None")&(df2["Type"]=="Compact")&(df2["Price"]<20)]
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11  12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 32  33         Ford     Tempo  Compact       10.4   11.3       12.2        22
# 67  68   Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# 73  74      Pontiac   Sunbird  Compact        9.4   11.1       12.8        23
#
#     MPG.highway AirBags  ... Passengers Length  Wheelbase  Width  Turn.circle  \
# 11           36    None  ...          5    182        101     66           38
# 32           27    None  ...          5    177        100     68           39
# 67           31    None  ...          5    188        103     67           39
# 73           31    None  ...          5    181        101     66           39
#
#     Rear.seat.room Luggage.room  Weight  Origin                Make
# 11            25.0         13.0    2490     USA  Chevrolet Cavalier
# ...

# %% [markdown]
# ## Que 5: Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.

# %%
ec=df2.sort_values(by="MPG.city",ascending=False).head(7)
ec
# Out:
#     id Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo    Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda    Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki    Swift  Small        7.3    8.6       10.0        39
# 79  80       Subaru    Justy  Small        7.3    8.4        9.5        33
# 83  84       Toyota   Tercel  Small        7.8    9.8       11.8        32
# 72  73      Pontiac   LeMans  Small        8.2    9.0        9.9        31
# 30  31         Ford  Festiva  Small        6.9    7.4        7.9        31
#
#     MPG.highway      AirBags  ... Passengers Length  Wheelbase  Width  \
# 38           50         None  ...          4    151         93     63
# 41           46  Driver only  ...          4    173        103     67
# 82           43         None  ...          4    161         93     63
# 79           37         None  ...          4    146         90     60
# ...

# %%
ec.sort_values(by="Horsepower",ascending=False)[["Manufacturer","Model","MPG.city","Horsepower"]]
# Out:
#    Manufacturer    Model  MPG.city  Horsepower
# 41        Honda    Civic        42         102
# 83       Toyota   Tercel        32          82
# 72      Pontiac   LeMans        31          74
# 79       Subaru    Justy        33          73
# 82       Suzuki    Swift        39          70
# 30         Ford  Festiva        31          63
# 38          Geo    Metro        46          55

# %% [markdown]
# ## Que 6:Find out Cars having mileage of more than 15 miles in city

# %%
df2[df2["MPG.city"]>15]
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# ## Que 7: Find out Cars with US based origin¶

# %%
df2["Origin"].unique()
# Out:
# array(['non-USA', 'USA'], dtype=object)

# %%
df2[df2["Origin"]=="USA"][["Manufacturer","Model","Origin"]]
# Out:
#    Manufacturer           Model Origin
# 5         Buick         Century    USA
# 6         Buick         LeSabre    USA
# 7         Buick      Roadmaster    USA
# 8         Buick         Riviera    USA
# 9      Cadillac         DeVille    USA
# 10     Cadillac         Seville    USA
# 11    Chevrolet        Cavalier    USA
# 12    Chevrolet         Corsica    USA
# 13    Chevrolet          Camaro    USA
# 14    Chevrolet          Lumina    USA
# 15    Chevrolet      Lumina_APV    USA
# 16    Chevrolet           Astro    USA
# 17    Chevrolet         Caprice    USA
# 18    Chevrolet        Corvette    USA
# 19     Chrylser        Concorde    USA
# 20     Chrysler         LeBaron    USA
# 21     Chrysler        Imperial    USA
# 22        Dodge            Colt    USA
# 23        Dodge          Shadow    USA
# 24        Dodge          Spirit    USA
# 25        Dodge         Caravan    USA
# 26        Dodge         Dynasty    USA
# 27        Dodge         Stealth    USA
# ...

# %% [markdown]
# ## Que 8: Find out Cars with no airbags and which are compact in type, from the output retrieve only Model, Mileage in city, Type, Airbags

# %%
df2[(df2["AirBags"]=="None")&(df2["Type"]=="Compact")][["Model","MPG.city","Type","AirBags"]]
# Out:
#        Model  MPG.city     Type AirBags
# 11  Cavalier        25  Compact    None
# 32     Tempo        22  Compact    None
# 67   Achieva        24  Compact    None
# 73   Sunbird        23  Compact    None
# 89    Passat        21  Compact    None

# %% [markdown]
# ## Que 9 :  Find out cars with Mileage in city more than 15 which are compact in type.

# %%
df2[(df2["MPG.city"]>15)&(df2["Type"]=="Compact")][["Manufacturer","Model","Type","MPG.city"]]
# Out:
#      Manufacturer     Model     Type  MPG.city
# 2            Audi        90  Compact        20
# 11      Chevrolet  Cavalier  Compact        25
# 12      Chevrolet   Corsica  Compact        25
# 20       Chrysler   LeBaron  Compact        23
# 24          Dodge    Spirit  Compact        22
# 32           Ford     Tempo  Compact        22
# 42          Honda    Accord  Compact        24
# 54          Mazda       626  Compact        26
# 57  Mercedes-Benz      190E  Compact        20
# 64         Nissan    Altima  Compact        24
# 67     Oldsmobile   Achieva  Compact        24
# 73        Pontiac   Sunbird  Compact        23
# 77           Saab       900  Compact        20
# 81         Subaru    Legacy  Compact        23
# 89     Volkswagen    Passat  Compact        21
# 91          Volvo       240  Compact        21
